# %%
# !pip install wavio
# !pip install librosa
# !pip install sounddevice
# !pip install pyaudio
# Out:
# ...
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.4 kB ? eta -:--:--
#      -------------------------------------- 60.4/60.4 kB 809.7 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#      --------------- ------------------------ 0.4/1.0 MB 8.1 MB/s eta 0:00:01
#      ---------------------------------------  1.0/1.0 MB 12.7 MB/s eta 0:00:01
#      ---------------------------------------- 1.0/1.0 MB 9.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/118.7 kB ? eta -:--:--
#      -------------------------------------- 118.7/118.7 kB 6.8 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/253.7 kB ? eta -:--:--
#    --------------------------------------- 253.7/253.7 kB 16.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/302.2 kB ? eta -:--:--
# ...

# %%
# import necessary modules
import sounddevice as sd

from scipy.io.wavfile import write
# %matplotlib inline
import matplotlib.pyplot as plt
import librosa.display
import IPython.display as ipd
# Define Sampling Rate or Frequency in Hz
sr = 44100


# Record duration in seconds
duration = 5
# Start audio recording
recording = sd.rec(int(duration*sr), samplerate=sr, channels=2) # we will record with a  mono or stereo channel microphone

# Record audio for the given duration
print("recording...............")
sd.wait()

# Write it to a file
write("sound3.wav",sr,recording)
# Look at the discrete number array we got from the audio
# Out:
# recording...............

# %%
# !pip install matplotlib==3.6.3

# %%
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", x.shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)
# Play the audio
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
# recording shape (110250,)
# sampling rate 22050
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import matplotlib
print('matplotlib: {}'.format(matplotlib.__version__))
# Out:
# matplotlib: 3.6.3

# %%
# Question 2
import numpy as np
import matplotlib.pyplot as plt
import librosa.display
import pylab
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import librosa    
import glob
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from keras import optimizers
import keras
from tensorflow.keras.utils import to_categorical

# %%
recorded_data = x
sampling_rate = sr

# %%
#delay1ms
wav_data, sampling_rate = librosa.load("sound3.wav", sr = 22050)
# third to last question
import numpy as np
wav_data=np.expand_dims(wav_data,axis=-1)
wav_data1ms=wav_data[:-22,:]
concatenatedata=np.concatenate((np.zeros([22,1]),wav_data1ms),axis=0)
delayed1ms=np.concatenate((concatenatedata,wav_data),axis=1)
# 4-183882-A-28
# 5-157204-B-16
# 1-19501-A-7
# 1-62594-A-32
print(audio_data.shape)
print(sampling_rate)
print(concatenatedata.shape)

#running channel 1 (delayed) concatenatedata
#run audio to check delay
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed1ms[:,0].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed1ms[:,0], sr=sr)
# Play the audio
ipd.Audio(delayed1ms[0], rate=sr) # load a NumPy array

#running channel 2 (original) wav_data
#run audio to check delay
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed1ms[:,1].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed1ms[:,1], sr=sr)
# Play the audio
ipd.Audio(delayed1ms[1], rate=sr) # load a NumPy array


#delay10ms
wav_data, sampling_rate = librosa.load("sound3.wav", sr = 22050)
# third to last question
import numpy as np
wav_data=np.expand_dims(wav_data,axis=-1)
wav_data10ms=wav_data[:-220,:]
concatenatedata=np.concatenate((np.zeros([220,1]),wav_data10ms),axis=0)
delayed10ms=np.concatenate((concatenatedata,wav_data),axis=1)
# 4-183882-A-28
# 5-157204-B-16
# 1-19501-A-7
# 1-62594-A-32
print(audio_data.shape)
print(sampling_rate)
print(concatenatedata.shape)

#running channel 1 (delayed) concatenatedata
#run audio to check delay
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed10ms[:,0].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed10ms[:,0], sr=sr)
# Play the audio
ipd.Audio(delayed10ms[0], rate=sr) # load a NumPy array

#running channel 2 (original) wav_data
#run audio to check delay
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed10ms[:,1].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed10ms[:,1], sr=sr)
# Play the audio
ipd.Audio(delayed10ms[1], rate=sr) # load a NumPy array

#delayed 100ms
wav_data, sampling_rate = librosa.load("sound3.wav", sr = 22050)
# third to last question
import numpy as np
wav_data=np.expand_dims(wav_data,axis=-1)
wav_data100ms=wav_data[:-2205,:]
concatenatedata=np.concatenate((np.zeros([2205,1]),wav_data100ms),axis=0)
delayed100ms=np.concatenate((concatenatedata,wav_data),axis=1)
# 4-183882-A-28
# 5-157204-B-16
# 1-19501-A-7
# 1-62594-A-32
print(audio_data.shape)
print(sampling_rate)
print(concatenatedata.shape)

#running channel 1 (delayed) concatenatedata
#run audio to check delay
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed100ms[:,0].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed100ms[:,0], sr=sr)
# Play the audio
ipd.Audio(delayed100ms[0], rate=sr) # load a NumPy array

#running channel 2 (original) wav_data
#run audio to check delay
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed100ms[:,1].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed100ms[:,1], sr=sr)
# Play the audio
#ipd.Audio(delayed1ms[1], rate=sr) # load a NumPy array

#delayed avghead = 11 zeros because 0.526 ms times 22050
#delayed 100ms
wav_data, sampling_rate = librosa.load("sound3.wav", sr = 22050)
# third to last question
import numpy as np
wav_data=np.expand_dims(wav_data,axis=-1)
wav_datahead=wav_data[:-11,:]
concatenatedata=np.concatenate((np.zeros([11,1]),wav_datahead),axis=0)
delayedhead=np.concatenate((concatenatedata,wav_data),axis=1)
# 4-183882-A-28
# 5-157204-B-16
# 1-19501-A-7
# 1-62594-A-32
print(audio_data.shape)
print(sampling_rate)
print(concatenatedata.shape)

#running channel 1 (delayed) concatenatedata
#run audio to check delay
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayedhead[:,0].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayedhead[:,0], sr=sr)
# Play the audio
ipd.Audio(delayedhead[0], rate=sr) # load a NumPy array

#running channel 2 (original) wav_data
#run audio to check delay
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayedhead[:,1].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayedhead[:,1], sr=sr)
# Play the audio
#ipd.Audio(delayed1ms[1], rate=sr) # load a NumPy array
# Out:
# (110250,)
# 22050
# (110250, 1)
# recording shape (110250,)
# sampling rate 22050
# recording shape (110250,)
# sampling rate 22050
# (110250,)
# 22050
# (110250, 1)
# recording shape (110250,)
# sampling rate 22050
# recording shape (110250,)
# sampling rate 22050
# (110250,)
# 22050
# (110250, 1)
# recording shape (110250,)
# sampling rate 22050
# recording shape (110250,)
# sampling rate 22050
# (110250,)
# 22050
# (110250, 1)
# recording shape (110250,)
# sampling rate 22050
# recording shape (110250,)
# sampling rate 22050

# %%
write('delayed1ms.wav',sr,delayed1ms)

# %%
x, sr = librosa.load('delayed1ms.wav')
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
write('delayed10ms.wav',sr,delayed10ms)

# %%
x, sr = librosa.load('delayed10ms.wav')
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
write('delayed100ms.wav',sr,delayed100ms)

# %%
x, sr = librosa.load('delayed100ms.wav')
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
write('delayedhead.wav',sr,delayedhead)

# %%
x, sr = librosa.load('delayedhead.wav')
ipd.Audio(x, rate=sr) # load a NumPy array
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#delay1ms
wav_data, sampling_rate = librosa.load("sound3.wav", sr = 22050)
# third to last question
import numpy as np
wav_data=np.expand_dims(wav_data,axis=-1)
wav_data1ms=wav_data[:-0,:]
concatenatedata=np.concatenate((np.multiply([0.5,0]),wav_data1ms),axis=0)
delayed1ms=np.concatenate((concatenatedata,wav_data),axis=1)
# 4-183882-A-28
# 5-157204-B-16
# 1-19501-A-7
# 1-62594-A-32
print(audio_data.shape)
print(sampling_rate)
print(concatenatedata.shape)

#running channel 1 (delayed) concatenatedata
#run audio to check delay
from librosa.display import waveshow
import librosa
import matplotlib.pyplot as plt
import IPython.display as ipd
x, sr = librosa.load('sound3.wav')
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed1ms[:,0].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed1ms[:,0], sr=sr)
# Play the audio
ipd.Audio(delayed1ms[0], rate=sr) # load a NumPy array

#running channel 2 (original) wav_data
#run audio to check delay
#change sound3.wav to different names for the different sentences. for example, sound3.wav
print("recording shape", delayed1ms[:,1].shape)
print("sampling rate", sr)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(delayed1ms[:,1], sr=sr)
# Play the audio
ipd.Audio(delayed1ms[1], rate=sr) # load a NumPy array
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[172], line 7
#       5 wav_data=np.expand_dims(wav_data,axis=-1)
#       6 wav_data1ms=wav_data[:-0,:]
# ----> 7 concatenatedata=np.concatenate((np.multiply([0.5,0]),wav_data1ms),axis=0)
#       8 delayed1ms=np.concatenate((concatenatedata,wav_data),axis=1)
#       9 # 4-183882-A-28
#      10 # 5-157204-B-16
#      11 # 1-19501-A-7
#      12 # 1-62594-A-32
#
# TypeError: multiply() takes from 2 to 3 positional arguments but 1 were given

# %%
plt.plot(wav_data)
plt.show()

# %%
freq = librosa.amplitude_to_db(np.abs(librosa.stft(wav_data)), ref=np.max)
print(freq.shape)
# Out:
# (1025, 216)

# %%
#fig, ax = plt.subplots(nrows=1, ncols=1, sharex=True)
fig, ax = plt.subplots(nrows=1, ncols=1, sharex=True)
spec = librosa.display.specshow(freq, y_axis='linear', sr=sr, x_axis='time')

# Limit the displayed frequency range to 8000 Hz
ax.set_ylim([0, 8000])

plt.show()

# %%
#recorded data, we are expected to see the same spectogram because it is not a lossy compression
freq = librosa.amplitude_to_db(np.abs(librosa.stft(recorded_data)), ref=np.max)
print(freq.shape)

#fig, ax = plt.subplots(nrows=1, ncols=1, sharex=True)
fig, ax = plt.subplots(nrows=1, ncols=1, sharex=True)
spec = librosa.display.specshow(freq, y_axis='linear', sr=sr, x_axis='time')

# Limit the displayed frequency range to 8000 Hz
ax.set_ylim([0, 8000])

plt.show()
# Out:
# (1025, 216)
